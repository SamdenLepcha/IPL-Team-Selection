# %% [markdown]
# <h1>Greetings</h1>

# %% [markdown]
# In this IPython notebook we have performed some basic EDA to better understand the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
two_019=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL2019.csv")

# %%
two_019['COUNTRY'].value_counts()
# Out:
# IND    123
# SA      14
# WI      13
# AUS     12
# NZ      10
# ENG      9
# AFG      3
# BGD      1
# SL       1
# NP       1
# Name: COUNTRY, dtype: int64

# %%
plt.figure(figsize=(12, 7))
sns.set_style("whitegrid")
sns.countplot(x='COUNTRY',data=two_019,palette='rainbow')

# %%
plt.figure(figsize=(12, 7))
sns.set_style("whitegrid")
sns.countplot(x='Age',data=Age,palette='rainbow')

# %%
plt.figure(figsize=(12, 7))
sns.set_style("whitegrid")
sns.countplot(x='Type',data=Age,palette='rainbow')

# %%
#Virat Kohli's Runs over the years
plt.figure(figsize=(12, 7))
sns.barplot(x='Year',y='Runs',data=kohli,palette='winter')

# %%
two_018=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL(2018-19).csv")
two_017=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL(2017-19).csv")
two_016=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL(2016-19).csv")
two_015=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL(2015-19).csv")
two_013=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL(2013-19).csv")
two_012=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL(2012-19).csv")
two_011=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL(2011-19).csv")
two_010=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL(2010-19).csv")

# %%
two_018['Player\'s Name']=two_018['Player\'s Name'].str.lstrip()
two_018['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()
two_017['Player\'s Name']=two_018['Player\'s Name'].str.lstrip()
two_017['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()
two_016['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()
two_016['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()
two_015['Player\'s Name']=two_018['Player\'s Name'].str.lstrip()
two_015['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()
two_014['Player\'s Name']=two_018['Player\'s Name'].str.lstrip()
two_014['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()
two_013['Player\'s Name']=two_018['Player\'s Name'].str.lstrip()
two_013['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()
two_012['Player\'s Name']=two_018['Player\'s Name'].str.lstrip()
two_012['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()
two_011['Player\'s Name']=two_018['Player\'s Name'].str.lstrip()
two_011['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()
two_010['Player\'s Name']=two_018['Player\'s Name'].str.lstrip()
two_010['Player\'s Name']=two_018['Player\'s Name'].str.rstrip()

# %%
two_010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 19 columns):
# Player's Name         35 non-null object
# Sl no                 35 non-null int64
# Team                  35 non-null object
# From                  34 non-null object
# Runs                  35 non-null int64
# Balls                 35 non-null int64
# Four                  35 non-null int64
# Six                   35 non-null int64
# Highest Run Scored    35 non-null int64
# Strike Rate           31 non-null float64
# Balls Bowled          35 non-null int64
# Runs Conceded         35 non-null int64
# Economy               20 non-null float64
# Wickets               35 non-null int64
# ct_st                 35 non-null int64
# Run Outs              35 non-null float64
# Matches Played        35 non-null int64
# Age                   32 non-null float64
# Type                  35 non-null object
# dtypes: float64(4), int64(11), object(4)
# memory usage: 5.3+ KB

# %%
two_010.head()
# Out:
#    Player's Name  Sl no Team From  Runs  Balls  Four  Six  Highest Run Scored  \
# 0       MS Dhoni    118  CSK  IND   287    210    24    9                  66
# 1   Suresh Raina    175  CSK  IND   524    365    46   22                  83
# 2  Deepak Chahar     59   MI   WI    64     53     4    4                  23
# 3        KM Asif    152   RR  AUS   185    114    18    9                  60
# 4    Karn Sharma     90   DD  IND    76     56     7    2                  50
#
#    Strike Rate  Balls Bowled  Runs Conceded   Economy  Wickets  ct_st  \
# 0   136.666667             0              0       NaN        0     11
# 1   143.561644           143            178  7.468531        6     10
# 2   120.754717           157            228  8.713376        4      4
# 3   162.280702           132            184  8.363636        6      3
# 4   135.714286             0              0       NaN        0      0
#
#    Run Outs  Matches Played   Age Type
# ...

# %%
two_010[two_010['Player\'s Name']=='Virat Kohli']

# %%
two_011[two_011['Player\'s Name']=='Virat Kohli']

# %%
two_012[two_012['Player\'s Name']=='Virat Kohli']

# %%
two_013[two_013['Player\'s Name']=='Virat Kohli']

# %%
two_014[two_014['Player\'s Name']=='Virat Kohli']

# %%
two_015[two_015['Player\'s Name']=='Virat Kohli']

# %%
two_016[two_016['Player\'s Name']=='Virat Kohli']

# %%
two_017[two_017['Player\'s Name']=='Virat Kohli']

# %%
two_018[two_018['Player\'s Name']=='Virat Kohli']

# %%
kohli=pd.DataFrame()

# %%
kohli.to_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/VK.csv")

# %%
kohli=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/VK.csv")

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(two_018.corr(),annot=True)

# %%
Age=pd.DataFrame()
temp=pd.DataFrame()

# %%
Age["Player's Name"]=two_011['Player\'s Name']

# %%
temp["Player's Name"]=two_017['Player\'s Name']

# %%
Age=pd.merge(Age,two_018,how='outer',on=["Player's Name"])

# %%
Age['Age'].fillna(value=0,inplace=True,axis=0)

# %%
Age.to_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/Age.csv")

# %%
Age=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/Age.csv")

# %%
Age.head()
# Out:
#   Player's Name  Sl.No Team From    Run   Ball Strike Rate   4's   6's  \
# 0      MS Dhoni  124.0  CSK  IND  455.0  302.0       150.7  24.0  30.0
# 1  Suresh Raina  179.0  CSK  IND  445.0  336.0       132.4  46.0  12.0
# 2  Dwayne Bravo   56.0  CSK   WI  141.0   91.0       154.9   8.0  10.0
# 3  Shane Watson  165.0  CSK  AUS  555.0  359.0       154.6  44.0  35.0
# 4  Kedar Jadhav   88.0  CSK  IND   24.0   22.0       109.1   1.0   2.0
#
#    Highest Run Scored  Balls  Bowled  Runs Scored Economy  Wickets  Ct_St  \
# 0                79.0            0.0          0.0       -      0.0   14.0
# 1                75.0            0.0          0.0       -      0.0    9.0
# 2                68.0          321.0        533.0      10     14.0    9.0
# 3               117.0          168.0        251.0       9      6.0    3.0
# 4                24.0            0.0          0.0       -      0.0    0.0
#
#    Run Outs  Matches Played  Age Type
# 0       4.0            16.0   37   WK
# ...

# %%
Dhoni=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/Dhoni.csv")

# %%
print(two_018['Run'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(two_018['Run'], color='g', bins=100, hist_kws={'alpha': 0.4})
# Out:
# count    130.000000
# mean     133.207692
# std      183.498165
# min        0.000000
# 25%        2.250000
# 50%       47.500000
# 75%      222.500000
# max      735.000000
# Name: Run, dtype: float64
# C:\Users\samde\Miniconda3\envs\AI\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (10, 6))
ax = sns.boxplot(x='Type', y="Run", data=two_018)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %%
plt.figure(figsize = (10, 6))
ax = sns.boxplot(x='Type', y='Run', data=two_018)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)

# %%
two_011.columns
# Out:
# Index(['Player's Name', 'Runs', 'Balls ', 'Strike Rate', 'Four', 'Six',
#        'Highest Runs Scored', 'Balls Bowled', 'Runs Conceded', 'Wicket',
#        'Economy', 'ct_st', 'Run Outs', 'Matches Played', 'Type'],
#       dtype='object')

# %%
two_011=two_011.rename(columns={'Runs': 'Runs11', 'Balls ': 'Balls11','Strike Rate':'Strike Rate11',
                                'Four':'Four11','Six':'Six11','Highest Runs Scored':'Highest Runs Scored11'
                               ,'Balls Bowled':'Balls Bowled11','Runs Conceded':'Runs Conceded11','Wicket':
                               'Wicket11','Economy':'Economy11','ct_st':'ct_st11','Run Outs':'Run Outs11',
                               'Matches Played':'Matches Played11'})

# %%
two_012.drop(['Age','Team','From','Sl No'],axis=1,inplace=True)

# %%
two_012.columns
# Out:
# Index(['Player's Name', 'Run', 'Ball', 'Strike Rate', 'Four', 'Six',
#        'Balls Bowled', 'Runs Concede', 'Economy', 'Wickets', 'Ct_St',
#        'Matches Played', 'Type'],
#       dtype='object')

# %%
two_012=two_011.rename(columns={'Run': 'Runs12', 'Ball ': 'Balls12','Strike Rate':'Strike Rate12',
                                'Four':'Four12','Six':'Six12'
                               ,'Balls Bowled':'Balls Bowled13','Runs Concede':'Runs Conceded12','Wickets':
                               'Wicket12','Economy':'Economy12','Ct_St':'ct_st12',
                               'Matches Played':'Matches Played12'})

# %%
combined=pd.merge(two_011,two_012,how='left',on=["Player's Name",'Type'])

# %%
combined.columns
# Out:
# Index(['Player's Name', 'Runs11_x', 'Balls11_x', 'Strike Rate11_x', 'Four11_x',
#        'Six11_x', 'Highest Runs Scored11_x', 'Balls Bowled11_x',
#        'Runs Conceded11_x', 'Wicket11_x', 'Economy11_x', 'ct_st11_x',
#        'Run Outs11_x', 'Matches Played11_x', 'Type', 'Runs11_y', 'Balls11_y',
#        'Strike Rate11_y', 'Four11_y', 'Six11_y', 'Highest Runs Scored11_y',
#        'Balls Bowled11_y', 'Runs Conceded11_y', 'Wicket11_y', 'Economy11_y',
#        'ct_st11_y', 'Run Outs11_y', 'Matches Played11_y'],
#       dtype='object')

# %%
#MS Dhoni Average Runs over the years
plt.figure(figsize=(12, 7))
sns.barplot(x='Year',y='Average',data=Dhoni,palette='winter')

# %%
two_014=pd.read_csv("C:/Users/samde/Desktop/Data Science/Datasets/IPL/IPL2014.csv")
